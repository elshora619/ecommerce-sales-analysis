# %%
import pandas as pd

df = pd.read_csv("ecommerce_sales_cleaned.csv")

df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Revenue  Month  Year
# 0  12/1/2010 0:00       2.55       17850  United Kingdom    15.30     12  2010
# 1  12/1/2010 0:00       3.39       17850  United Kingdom    20.34     12  2010
# 2  12/1/2010 0:00       2.75       17850  United Kingdom    22.00     12  2010
# 3  12/1/2010 0:00       3.39       17850  United Kingdom    20.34     12  2010
# 4  12/1/2010 0:00       3.39       17850  United Kingdom    20.34     12  2010

# %%
df.shape
# Out:
# (397924, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  int64
#  1   StockCode    397924 non-null  str
#  2   Description  397924 non-null  str
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  str
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  int64
#  7   Country      397924 non-null  str
#  8   Revenue      397924 non-null  float64
#  9   Month        397924 non-null  int64
#  10  Year         397924 non-null  int64
# dtypes: float64(2), int64(5), str(4)
# memory usage: 33.4 MB

# %%
df.describe()
# Out:
#            InvoiceNo       Quantity      UnitPrice     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   560617.126645      13.021823       3.116174   15294.315171
# std     13106.167695     180.420210      22.096788    1713.169877
# min    536365.000000       1.000000       0.000000   12346.000000
# 25%    549234.000000       2.000000       1.250000   13969.000000
# 50%    561893.000000       6.000000       1.950000   15159.000000
# 75%    572090.000000      12.000000       3.750000   16795.000000
# max    581587.000000   80995.000000    8142.750000   18287.000000
#
#              Revenue          Month           Year
# count  397924.000000  397924.000000  397924.000000
# mean       22.394749       7.612537    2010.934259
# std       309.055588       3.416527       0.247829
# min         0.000000       1.000000    2010.000000
# 25%         4.680000       5.000000    2011.000000
# 50%        11.800000       8.000000    2011.000000
# 75%        19.800000      11.000000    2011.000000
# max    168469.600000      12.000000    2011.000000

# %%
country_sales = df.groupby("Country")["Revenue"].sum().sort_values(ascending=False)

country_sales.head(10)
# Out:
# Country
# United Kingdom    7308391.554
# Netherlands        285446.340
# EIRE               265545.900
# Germany            228867.140
# France             209024.050
# Australia          138521.310
# Spain               61577.110
# Switzerland         56443.950
# Belgium             41196.340
# Sweden              38378.330
# Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_countries = country_sales.head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_countries.values, y=top_countries.index)

plt.title("Top 10 Countries by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Country")

plt.show()

# %%
monthly_sales = df.groupby("Month")["Revenue"].sum()

monthly_sales
# Out:
# Month
# 1      569445.040
# 2      447137.350
# 3      595500.760
# 4      469200.361
# 5      678594.560
# 6      661213.690
# 7      600091.011
# 8      645343.900
# 9      952838.382
# 10    1039318.790
# 11    1161817.380
# 12    1090906.680
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(10,6))

sns.lineplot(x=monthly_sales.index, y=monthly_sales.values)

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")

plt.show()

# %%
top_products = df.groupby("Description")["Revenue"].sum().sort_values(ascending=False)

top_products.head(10)
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# REGENCY CAKESTAND 3 TIER              142592.95
# WHITE HANGING HEART T-LIGHT HOLDER    100448.15
# JUMBO BAG RED RETROSPOT                85220.78
# MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# POSTAGE                                77803.96
# PARTY BUNTING                          68844.33
# ASSORTED COLOUR BIRD ORNAMENT          56580.34
# Manual                                 53779.93
# RABBIT NIGHT LIGHT                     51346.20
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(10,6))

sns.barplot(x=top_products.head(10).values, y=top_products.head(10).index)

plt.title("Top 10 Products by Revenue")

plt.show()

# %%
df.shape
# Out:
# (397924, 11)
